# %% [markdown]
# Live view data prepare
# ---

# %% [markdown]
# # load photos

# %%
import PIL
import os
import numpy as np

live_view_folder = '../photos/live_view/'
photo_files = os.listdir(live_view_folder)

def import_image(path):
    image_data = False
    try:
        with PIL.Image.open(path) as an_image:
            image_data = an_image.copy()
        return image_data
    except:
        pass

live_images = [
    import_image( os.path.join(live_view_folder, file))
    for file in photo_files if file.endswith('.jpg')         
]

# %%
import datetime as dt
import pandas as pd

# %%
#the last few don't exist yet.
live_images = live_images

# %%
all_live_images = np.array([
    np.array(image)
    for image in live_images
])

# %%
#get some statistics on each image
sums = [
    np.sum(image)
    for image in live_images
]

import matplotlib.pyplot as plt

plt.plot(sums)
plt.title('total brightness')
# Out:
# Text(0.5, 1.0, 'total brightness')

# %%
np.unique([np.array(image).shape for image in live_images])
# Out:
# array([   3,  720, 1024])

# %% [markdown]
# all images are 1024x720x3

# %%
exif_data = [
    [thing
    for thing in live_image.getexif().items()]
    for live_image in live_images
]

exif_data[:4]
# Out:
# [[(296, 2),
#   (34665, 300),
#   (271, 'RECONYX'),
#   (272, 'HF2 PRO COVERT\x00\x00\x00\x00\x00'),
#   (306, '2024:09:17 19:30:00'),
#   (531, 2),
#   (282, 72.0),
#   (283, 72.0)],
#  [(296, 2),
#   (34665, 300),
#   (271, 'RECONYX'),
#   (272, 'HF2 PRO COVERT\x00\x00\x00\x00\x00'),
#   (306, '2024:09:17 19:45:00'),
#   (531, 2),
#   (282, 72.0),
#   (283, 72.0)],
#  [(296, 2),
#   (34665, 300),
#   (271, 'RECONYX'),
#   (272, 'HF2 PRO COVERT\x00\x00\x00\x00\x00'),
#   (306, '2024:09:17 20:00:00'),
#   (531, 2),
#   (282, 72.0),
#   (283, 72.0)],
#  [(296, 2),
#   (34665, 300),
#   (271, 'RECONYX'),
#   (272, 'HF2 PRO COVERT\x00\x00\x00\x00\x00'),
#   (306, '2024:09:17 20:15:00'),
#   (531, 2),
#   (282, 72.0),
#   (283, 72.0)]]

# %%
#image dataframe.

codes = [296, 34665, 271, 272, 306, 531, 282, 283]

col_to_code = dict(zip(
    range(8),
    codes
))

descriptions = [
    'Resolution unit',
    'ExifIFDPointer',
    'Make',
    'Model',
    'date',
    'YCbCrPositioning',
    'XResolution',
    'YResolution'    
]

code_to_description = dict(zip( codes, descriptions))


col_to_description = dict(zip(range(8), descriptions))

idf = pd.DataFrame(exif_data)

idf.rename(columns = col_to_description, inplace=True)

idf = idf.map(lambda entry: entry[1])
idf
# Out:
#       Resolution unit  ExifIFDPointer     Make                Model  \
# 0                   2             300  RECONYX  HF2 PRO COVERT
# 1                   2             300  RECONYX  HF2 PRO COVERT
# 2                   2             300  RECONYX  HF2 PRO COVERT
# 3                   2             300  RECONYX  HF2 PRO COVERT
# 4                   2             300  RECONYX  HF2 PRO COVERT
# ...               ...             ...      ...                  ...
# 1222                2             300  RECONYX  HF2 PRO COVERT
# 1223                2             300  RECONYX  HF2 PRO COVERT
# 1224                2             300  RECONYX  HF2 PRO COVERT
# 1225                2             300  RECONYX  HF2 PRO COVERT
# 1226                2             300  RECONYX  HF2 PRO COVERT
#
#                      date  YCbCrPositioning XResolution YResolution
# 0     2024:09:17 19:30:00                 2        72.0        72.0
# 1     2024:09:17 19:45:00                 2        72.0        72.0
# 2     2024:09:17 20:00:00                 2        72.0        72.0
# 3     2024:09:17 20:15:00                 2        72.0        72.0
# 4     2024:09:17 20:30:00                 2        72.0        72.0
# ...                   ...               ...         ...         ...
# 1222  2024:09:29 11:45:00                 2        72.0        72.0
# 1223  2024:09:29 12:00:00                 2        72.0        72.0
# 1224  2024:09:29 12:01:49                 2        72.0        72.0
# 1225  2024:09:29 12:15:00                 2        72.0        72.0
# 1226  2024:09:29 12:30:00                 2        72.0        72.0
#
# [1227 rows x 8 columns]

# %%
idf['date'] = pd.to_datetime(idf['date'], format = '%Y:%m:%d %H:%M:%S')

idf
# Out:
#       Resolution unit  ExifIFDPointer     Make                Model  \
# 0                   2             300  RECONYX  HF2 PRO COVERT
# 1                   2             300  RECONYX  HF2 PRO COVERT
# 2                   2             300  RECONYX  HF2 PRO COVERT
# 3                   2             300  RECONYX  HF2 PRO COVERT
# 4                   2             300  RECONYX  HF2 PRO COVERT
# ...               ...             ...      ...                  ...
# 1222                2             300  RECONYX  HF2 PRO COVERT
# 1223                2             300  RECONYX  HF2 PRO COVERT
# 1224                2             300  RECONYX  HF2 PRO COVERT
# 1225                2             300  RECONYX  HF2 PRO COVERT
# 1226                2             300  RECONYX  HF2 PRO COVERT
#
#                     date  YCbCrPositioning XResolution YResolution
# 0    2024-09-17 19:30:00                 2        72.0        72.0
# 1    2024-09-17 19:45:00                 2        72.0        72.0
# 2    2024-09-17 20:00:00                 2        72.0        72.0
# 3    2024-09-17 20:15:00                 2        72.0        72.0
# 4    2024-09-17 20:30:00                 2        72.0        72.0
# ...                  ...               ...         ...         ...
# 1222 2024-09-29 11:45:00                 2        72.0        72.0
# 1223 2024-09-29 12:00:00                 2        72.0        72.0
# 1224 2024-09-29 12:01:49                 2        72.0        72.0
# 1225 2024-09-29 12:15:00                 2        72.0        72.0
# 1226 2024-09-29 12:30:00                 2        72.0        72.0
#
# [1227 rows x 8 columns]

# %%
idf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1227 entries, 0 to 1226
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Resolution unit   1227 non-null   int64
#  1   ExifIFDPointer    1227 non-null   int64
#  2   Make              1227 non-null   object
#  3   Model             1227 non-null   object
#  4   date              1227 non-null   datetime64[ns]
#  5   YCbCrPositioning  1227 non-null   int64
#  6   XResolution       1227 non-null   object
#  7   YResolution       1227 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 76.8+ KB

# %%
idf.plot('date', 'Resolution unit', kind = 'scatter', figsize = (12,5))
# Out:
# <Axes: xlabel='date', ylabel='Resolution unit'>

# %%
idf
# Out:
#       Resolution unit  ExifIFDPointer     Make                Model  \
# 0                   2             300  RECONYX  HF2 PRO COVERT
# 1                   2             300  RECONYX  HF2 PRO COVERT
# 2                   2             300  RECONYX  HF2 PRO COVERT
# 3                   2             300  RECONYX  HF2 PRO COVERT
# 4                   2             300  RECONYX  HF2 PRO COVERT
# ...               ...             ...      ...                  ...
# 1222                2             300  RECONYX  HF2 PRO COVERT
# 1223                2             300  RECONYX  HF2 PRO COVERT
# 1224                2             300  RECONYX  HF2 PRO COVERT
# 1225                2             300  RECONYX  HF2 PRO COVERT
# 1226                2             300  RECONYX  HF2 PRO COVERT
#
#                     date  YCbCrPositioning XResolution YResolution
# 0    2024-09-17 19:30:00                 2        72.0        72.0
# 1    2024-09-17 19:45:00                 2        72.0        72.0
# 2    2024-09-17 20:00:00                 2        72.0        72.0
# 3    2024-09-17 20:15:00                 2        72.0        72.0
# 4    2024-09-17 20:30:00                 2        72.0        72.0
# ...                  ...               ...         ...         ...
# 1222 2024-09-29 11:45:00                 2        72.0        72.0
# 1223 2024-09-29 12:00:00                 2        72.0        72.0
# 1224 2024-09-29 12:01:49                 2        72.0        72.0
# 1225 2024-09-29 12:15:00                 2        72.0        72.0
# 1226 2024-09-29 12:30:00                 2        72.0        72.0
#
# [1227 rows x 8 columns]

# %%
np.array(live_images[0]).shape
# Out:
# (720, 1024, 3)

# %%
#save image shape
for index in idf.index:
    # print(index)
    idf.loc[index, 'image_shape'] = str(np.array(live_images[int(index)]).shape)

#save some statistics about each image

#get the sum of the numpy array data
for index in idf.index:
    idf.loc[index, 'sum_brightness'] = np.array(live_images[index]).sum()
    
idf
# Out:
#       Resolution unit  ExifIFDPointer     Make                Model  \
# 0                   2             300  RECONYX  HF2 PRO COVERT
# 1                   2             300  RECONYX  HF2 PRO COVERT
# 2                   2             300  RECONYX  HF2 PRO COVERT
# 3                   2             300  RECONYX  HF2 PRO COVERT
# 4                   2             300  RECONYX  HF2 PRO COVERT
# ...               ...             ...      ...                  ...
# 1222                2             300  RECONYX  HF2 PRO COVERT
# 1223                2             300  RECONYX  HF2 PRO COVERT
# 1224                2             300  RECONYX  HF2 PRO COVERT
# 1225                2             300  RECONYX  HF2 PRO COVERT
# 1226                2             300  RECONYX  HF2 PRO COVERT
#
#                     date  YCbCrPositioning XResolution YResolution  \
# 0    2024-09-17 19:30:00                 2        72.0        72.0
# 1    2024-09-17 19:45:00                 2        72.0        72.0
# 2    2024-09-17 20:00:00                 2        72.0        72.0
# 3    2024-09-17 20:15:00                 2        72.0        72.0
# 4    2024-09-17 20:30:00                 2        72.0        72.0
# ...                  ...               ...         ...         ...
# 1222 2024-09-29 11:45:00                 2        72.0        72.0
# 1223 2024-09-29 12:00:00                 2        72.0        72.0
# 1224 2024-09-29 12:01:49                 2        72.0        72.0
# 1225 2024-09-29 12:15:00                 2        72.0        72.0
# 1226 2024-09-29 12:30:00                 2        72.0        72.0
#
#          image_shape  sum_brightness
# 0     (720, 1024, 3)     145126194.0
# 1     (720, 1024, 3)     145193808.0
# 2     (720, 1024, 3)     138221787.0
# 3     (720, 1024, 3)     145079076.0
# 4     (720, 1024, 3)     145181379.0
# ...              ...             ...
# 1222  (720, 1024, 3)     217385538.0
# 1223  (720, 1024, 3)     208813362.0
# 1224  (720, 1024, 3)     207050374.0
# 1225  (720, 1024, 3)     200887316.0
# 1226  (720, 1024, 3)     220614012.0
#
# [1227 rows x 10 columns]

# %%
idf.plot(x='date', y='sum_brightness')
# Out:
# <Axes: xlabel='date'>

# %%
idf.loc[idf['sum_brightness'] == idf['sum_brightness'].drop([349, 350]).min()]
# Out:
#      Resolution unit  ExifIFDPointer     Make                Model  \
# 223                2             300  RECONYX  HF2 PRO COVERT
#
#                    date  YCbCrPositioning XResolution YResolution  \
# 223 2024-09-19 23:23:58                 2        72.0        72.0
#
#         image_shape  sum_brightness
# 223  (720, 1024, 3)      80078049.0

# %%
def display_value_counts(dataframe, column, vc_limit = 5, normalize = True):
    value_counts = dataframe[column].value_counts(normalize = normalize)
    if len(value_counts) <= vc_limit:
        print(value_counts)
    else:
        print(f"{column} has \t{len(value_counts)} distinct values")

hbar = '='*50

print(hbar)
for column in idf.columns:
    display_value_counts(idf, column)
    print(hbar)
# Out:
# ==================================================
# Resolution unit
# 2    1.0
# Name: proportion, dtype: float64
# ==================================================
# ExifIFDPointer
# 300    1.0
# Name: proportion, dtype: float64
# ==================================================
# Make
# RECONYX    1.0
# Name: proportion, dtype: float64
# ==================================================
# Model
# HF2 PRO COVERT    1.0
# Name: proportion, dtype: float64
# ==================================================
# date has 	1219 distinct values
# ==================================================
# YCbCrPositioning
# 2    1.0
# Name: proportion, dtype: float64
# ==================================================
# XResolution
# 72.0    1.0
# Name: proportion, dtype: float64
# ==================================================
# YResolution
# 72.0    1.0
# Name: proportion, dtype: float64
# ==================================================
# image_shape
# (720, 1024, 3)    1.0
# Name: proportion, dtype: float64
# ==================================================
# sum_brightness has 	1223 distinct values
# ==================================================

# %%
idf['date'].value_counts(ascending = False)[:20]
# Out:
# date
# 2024-09-29 05:41:12    3
# 2024-09-20 22:30:00    2
# 2024-09-20 22:17:55    2
# 2024-09-20 22:17:48    2
# 2024-09-19 00:27:48    2
# 2024-09-20 22:18:02    2
# 2024-09-20 22:17:53    2
# 2024-09-25 14:30:00    1
# 2024-09-25 14:15:00    1
# 2024-09-25 14:00:00    1
# 2024-09-25 13:45:00    1
# 2024-09-25 13:30:00    1
# 2024-09-17 19:30:00    1
# 2024-09-25 13:15:00    1
# 2024-09-25 15:00:00    1
# 2024-09-25 13:00:00    1
# 2024-09-25 12:45:00    1
# 2024-09-25 12:30:00    1
# 2024-09-25 12:15:00    1
# 2024-09-25 12:01:49    1
# Name: count, dtype: int64

# %%
sum_brightness_vcs = idf['sum_brightness'].value_counts(ascending = False)
#for every sum_brightness vcs greater than 1, get the entries with that value.

for thing in sum_brightness_vcs:
    pass

# %%
#strange. there are six duplicate sets of times.
#but only 3 duplicate sets of sum brightness. So these aren't all just copies.

for this_sum in sum_brightness_vcs.index:
    if sum_brightness_vcs[this_sum] > 1:
        print(idf.loc[ idf['sum_brightness'] == this_sum ])
# Out:
#      Resolution unit  ExifIFDPointer     Make                Model  \
# 338                2             300  RECONYX  HF2 PRO COVERT
# 339                2             300  RECONYX  HF2 PRO COVERT
#
#                    date  YCbCrPositioning XResolution YResolution  \
# 338 2024-09-20 22:17:53                 2        72.0        72.0
# 339 2024-09-20 22:17:53                 2        72.0        72.0
#
#         image_shape  sum_brightness
# 338  (720, 1024, 3)     152279781.0
# 339  (720, 1024, 3)     152279781.0
#       Resolution unit  ExifIFDPointer     Make                Model  \
# 1190                2             300  RECONYX  HF2 PRO COVERT
# 1191                2             300  RECONYX  HF2 PRO COVERT
#
#                     date  YCbCrPositioning XResolution YResolution  \
# 1190 2024-09-29 05:41:12                 2        72.0        72.0
# 1191 2024-09-29 05:41:12                 2        72.0        72.0
#
#          image_shape  sum_brightness
# 1190  (720, 1024, 3)     143494479.0
# 1191  (720, 1024, 3)     143494479.0
#      Resolution unit  ExifIFDPointer     Make                Model  \
# 122                2             300  RECONYX  HF2 PRO COVERT
# 123                2             300  RECONYX  HF2 PRO COVERT
#
#                    date  YCbCrPositioning XResolution YResolution  \
# 122 2024-09-19 00:27:48                 2        72.0        72.0
# 123 2024-09-19 00:27:48                 2        72.0        72.0
#
#         image_shape  sum_brightness
# 122  (720, 1024, 3)     137538549.0
# 123  (720, 1024, 3)     137538549.0
#      Resolution unit  ExifIFDPointer     Make                Model  \
# 361                2             300  RECONYX  HF2 PRO COVERT
# 362                2             300  RECONYX  HF2 PRO COVERT
#
#                    date  YCbCrPositioning XResolution YResolution  \
# 361 2024-09-20 22:30:00                 2        72.0        72.0
# 362 2024-09-20 22:30:00                 2        72.0        72.0
#
#         image_shape  sum_brightness
# 361  (720, 1024, 3)     142679574.0
# 362  (720, 1024, 3)     142679574.0

# %%
#ok, so the three sets with the same sum are all taken at the same time. These may be repeat images.

#so the other three sets are photos taken at different times with the same sum brightness. What're the odds of that??

date_vcs = idf['date'].value_counts(ascending = False)

same_date_index = []

for this_date in date_vcs.index:
    if date_vcs[this_date] > 1:
        this_date_mask = idf['date'] == this_date
        print(idf.loc[ this_date_mask ])
        same_date_index = same_date_index +  list(idf.loc[this_date_mask].index)
same_date_index
# Out:
#       Resolution unit  ExifIFDPointer     Make                Model  \
# 1189                2             300  RECONYX  HF2 PRO COVERT
# 1190                2             300  RECONYX  HF2 PRO COVERT
# 1191                2             300  RECONYX  HF2 PRO COVERT
#
#                     date  YCbCrPositioning XResolution YResolution  \
# 1189 2024-09-29 05:41:12                 2        72.0        72.0
# 1190 2024-09-29 05:41:12                 2        72.0        72.0
# 1191 2024-09-29 05:41:12                 2        72.0        72.0
#
#          image_shape  sum_brightness
# 1189  (720, 1024, 3)     143392389.0
# 1190  (720, 1024, 3)     143494479.0
# 1191  (720, 1024, 3)     143494479.0
#      Resolution unit  ExifIFDPointer     Make                Model  \
# 361                2             300  RECONYX  HF2 PRO COVERT
# 362                2             300  RECONYX  HF2 PRO COVERT
#
#                    date  YCbCrPositioning XResolution YResolution  \
# 361 2024-09-20 22:30:00                 2        72.0        72.0
# 362 2024-09-20 22:30:00                 2        72.0        72.0
#
#         image_shape  sum_brightness
# 361  (720, 1024, 3)     142679574.0
# 362  (720, 1024, 3)     142679574.0
#      Resolution unit  ExifIFDPointer     Make                Model  \
# 341                2             300  RECONYX  HF2 PRO COVERT
# 342                2             300  RECONYX  HF2 PRO COVERT
#
#                    date  YCbCrPositioning XResolution YResolution  \
# 341 2024-09-20 22:17:55                 2        72.0        72.0
# 342 2024-09-20 22:17:55                 2        72.0        72.0
#
#         image_shape  sum_brightness
# 341  (720, 1024, 3)     152099583.0
# 342  (720, 1024, 3)     151822173.0
#      Resolution unit  ExifIFDPointer     Make                Model  \
# 333                2             300  RECONYX  HF2 PRO COVERT
# 334                2             300  RECONYX  HF2 PRO COVERT
#
#                    date  YCbCrPositioning XResolution YResolution  \
# 333 2024-09-20 22:17:48                 2        72.0        72.0
# 334 2024-09-20 22:17:48                 2        72.0        72.0
#
#         image_shape  sum_brightness
# 333  (720, 1024, 3)     153159039.0
# 334  (720, 1024, 3)     152885130.0
#      Resolution unit  ExifIFDPointer     Make                Model  \
# 122                2             300  RECONYX  HF2 PRO COVERT
# 123                2             300  RECONYX  HF2 PRO COVERT
#
#                    date  YCbCrPositioning XResolution YResolution  \
# 122 2024-09-19 00:27:48                 2        72.0        72.0
# 123 2024-09-19 00:27:48                 2        72.0        72.0
#
#         image_shape  sum_brightness
# 122  (720, 1024, 3)     137538549.0
# 123  (720, 1024, 3)     137538549.0
#      Resolution unit  ExifIFDPointer     Make                Model  \
# 346                2             300  RECONYX  HF2 PRO COVERT
# 347                2             300  RECONYX  HF2 PRO COVERT
#
#                    date  YCbCrPositioning XResolution YResolution  \
# 346 2024-09-20 22:18:02                 2        72.0        72.0
# 347 2024-09-20 22:18:02                 2        72.0        72.0
#
#         image_shape  sum_brightness
# 346  (720, 1024, 3)     136269384.0
# 347  (720, 1024, 3)     137175582.0
#      Resolution unit  ExifIFDPointer     Make                Model  \
# 338                2             300  RECONYX  HF2 PRO COVERT
# 339                2             300  RECONYX  HF2 PRO COVERT
#
#                    date  YCbCrPositioning XResolution YResolution  \
# 338 2024-09-20 22:17:53                 2        72.0        72.0
# 339 2024-09-20 22:17:53                 2        72.0        72.0
#
#         image_shape  sum_brightness
# 338  (720, 1024, 3)     152279781.0
# 339  (720, 1024, 3)     152279781.0
# [1189, 1190, 1191, 361, 362, 341, 342, 333, 334, 122, 123, 346, 347, 338, 339]

# %%
idf
# Out:
#       Resolution unit  ExifIFDPointer     Make                Model  \
# 0                   2             300  RECONYX  HF2 PRO COVERT
# 1                   2             300  RECONYX  HF2 PRO COVERT
# 2                   2             300  RECONYX  HF2 PRO COVERT
# 3                   2             300  RECONYX  HF2 PRO COVERT
# 4                   2             300  RECONYX  HF2 PRO COVERT
# ...               ...             ...      ...                  ...
# 1222                2             300  RECONYX  HF2 PRO COVERT
# 1223                2             300  RECONYX  HF2 PRO COVERT
# 1224                2             300  RECONYX  HF2 PRO COVERT
# 1225                2             300  RECONYX  HF2 PRO COVERT
# 1226                2             300  RECONYX  HF2 PRO COVERT
#
#                     date  YCbCrPositioning XResolution YResolution  \
# 0    2024-09-17 19:30:00                 2        72.0        72.0
# 1    2024-09-17 19:45:00                 2        72.0        72.0
# 2    2024-09-17 20:00:00                 2        72.0        72.0
# 3    2024-09-17 20:15:00                 2        72.0        72.0
# 4    2024-09-17 20:30:00                 2        72.0        72.0
# ...                  ...               ...         ...         ...
# 1222 2024-09-29 11:45:00                 2        72.0        72.0
# 1223 2024-09-29 12:00:00                 2        72.0        72.0
# 1224 2024-09-29 12:01:49                 2        72.0        72.0
# 1225 2024-09-29 12:15:00                 2        72.0        72.0
# 1226 2024-09-29 12:30:00                 2        72.0        72.0
#
#          image_shape  sum_brightness
# 0     (720, 1024, 3)     145126194.0
# 1     (720, 1024, 3)     145193808.0
# 2     (720, 1024, 3)     138221787.0
# 3     (720, 1024, 3)     145079076.0
# 4     (720, 1024, 3)     145181379.0
# ...              ...             ...
# 1222  (720, 1024, 3)     217385538.0
# 1223  (720, 1024, 3)     208813362.0
# 1224  (720, 1024, 3)     207050374.0
# 1225  (720, 1024, 3)     200887316.0
# 1226  (720, 1024, 3)     220614012.0
#
# [1227 rows x 10 columns]

# %%
#save image dataframe
idf.to_csv('../photos/live_image_df.csv', index= None)

# %%
#show all same-date guys
idf.loc[same_date_index]

#add a new column linking them to the other
for index, record in idf.iterrows():
    this_date = record['date']
    this_brightness = record['sum_brightness']
    shared_date_index = idf.loc[(idf.drop(index)['date'] == this_date)].index
    shared_brightness_index = idf.loc[(idf.drop(index)['sum_brightness'] == this_brightness)].index
    idf.loc[index, 'shares_date_with'] = str(shared_date_index)
    idf.loc[index, 'shares_brightness_with'] = str(shared_brightness_index)

idf
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[33], line 8
#       6 this_date = record['date']
#       7 this_brightness = record['sum_brightness']
# ----> 8 shared_date_index = idf.loc[(idf.drop(index)['date'] == this_date)].index
#       9 shared_brightness_index = idf.loc[(idf.drop(index)['sum_brightness'] == this_brightness)].index
#      10 idf.loc[index, 'shares_date_with'] = str(shared_date_index)
#
# File C:\Program Files\Python312\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\Program Files\Python312\Lib\site-packages\pandas\core\indexing.py:1413, in _LocIndexer._getitem_axis(self, key, axis)
#    1411     return self._get_slice_axis(key, axis=axis)
#    1412 elif com.is_bool_indexer(key):
# -> 1413     return self._getbool_axis(key, axis=axis)
#    1414 elif is_list_like_indexer(key):
#    1415     # an iterable multi-selection
#    1416     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File C:\Program Files\Python312\Lib\site-packages\pandas\core\indexing.py:1209, in _LocationIndexer._getbool_axis(self, key, axis)
#    1205 @final
#    1206 def _getbool_axis(self, key, axis: AxisInt):
#    1207     # caller is responsible for ensuring non-None axis
#    1208     labels = self.obj._get_axis(axis)
# -> 1209     key = check_bool_indexer(labels, key)
#    1210     inds = key.nonzero()[0]
#    1211     return self.obj._take_with_is_copy(inds, axis=axis)
#
# File C:\Program Files\Python312\Lib\site-packages\pandas\core\indexing.py:2662, in check_bool_indexer(index, key)
#    2660 indexer = result.index.get_indexer_for(index)
#    2661 if -1 in indexer:
# -> 2662     raise IndexingError(
#    2663         "Unalignable boolean Series provided as "
#    2664         "indexer (index of the boolean Series and of "
#    2665         "the indexed object do not match)."
#    2666     )
#    2668 result = result.take(indexer)
#    2670 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).
