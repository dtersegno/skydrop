# %% [markdown]
# Compare meteo temp data with image temps
# ---

# %%
import pandas as pd
import os
from numpy import intersect1d
import matplotlib.pyplot as plt


#load data from live_view images
text_data_file = '../weather-data/tesseract/live_view_inted.csv'
livetemp = pd.read_csv(text_data_file, index_col = None)
livetemp

#load data from meteo
meteo_data_file = '../weather-data/meteostat/devries-centered-75mi.csv'
meteodata = pd.read_csv(meteo_data_file, index_col=None)

#load image data with times
image_data_file = '../photos/live_image_df.csv'
idf = pd.read_csv(image_data_file, index_col=None)

#convert to datetime
meteodata['datetime'] = pd.to_datetime(meteodata['time'])
idf['datetime'] = pd.to_datetime(idf['date'])
                                 
# meteodata.join(livetemp, lsuffix="_meteo", rsuffix='_livetemp')

#tack livetemp on
idf = idf.join(livetemp)

#convert livetemp to centigrade
idf['tempc'] = (idf['temp']-32)*(5/9)

# %%
#plot the temperatures

fig, ax = plt.subplots(figsize=(10,6))

for station in meteodata['station'].unique():
    this_station_data = meteodata.loc[meteodata['station'] == station]
    # data_noindex.loc[data_noindex['station'] == station].plot(x='time', y='temp')
    ax.plot(this_station_data['datetime'], this_station_data['temp'], label=station, linestyle='--')

idf.plot(x='datetime', y='tempc', label = 'live image data', ax=ax, color = 'red', linestyle='-', linewidth = 2)

plt.legend()


plt.show()

# %%
#make a list of unique stations
stations = meteodata['station'].value_counts().index


#make a 15 minute interpolation data for each station

station_intertemps = {}
for station in stations:
    station_mask = meteodata['station'] == station
    this_data = meteodata.loc[station_mask, ['temp','datetime']]
    this_data_series = this_data.set_index('datetime')
    this_15min_data = this_data_series.resample('15min').interpolate()
    station_intertemps.update({station:this_15min_data})

#perform a cross-correlation with the temperature data and these series
station_intertemps['74410'].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
idf['datetime']
# Out:
# 0      2024-09-17 19:30:00
# 1      2024-09-17 19:45:00
# 2      2024-09-17 20:00:00
# 3      2024-09-17 20:15:00
# 4      2024-09-17 20:30:00
#                ...
# 1010   2024-09-27 11:15:00
# 1011   2024-09-27 11:30:00
# 1012   2024-09-27 11:45:00
# 1013   2024-09-27 12:00:00
# 1014   2024-09-27 12:01:49
# Name: datetime, Length: 1015, dtype: datetime64[ns]

# %%
station_intertemps['74410'].index
# Out:
# DatetimeIndex(['2024-09-17 00:00:00', '2024-09-17 00:15:00',
#                '2024-09-17 00:30:00', '2024-09-17 00:45:00',
#                '2024-09-17 01:00:00', '2024-09-17 01:15:00',
#                '2024-09-17 01:30:00', '2024-09-17 01:45:00',
#                '2024-09-17 02:00:00', '2024-09-17 02:15:00',
#                ...
#                '2024-09-26 21:45:00', '2024-09-26 22:00:00',
#                '2024-09-26 22:15:00', '2024-09-26 22:30:00',
#                '2024-09-26 22:45:00', '2024-09-26 23:00:00',
#                '2024-09-26 23:15:00', '2024-09-26 23:30:00',
#                '2024-09-26 23:45:00', '2024-09-27 00:00:00'],
#               dtype='datetime64[ns]', name='datetime', length=961, freq='15min')

# %%
aligned_data = station_intertemps['74410'].join(img_temps, on='datetime')

# %%
aligned_data.plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
aligned_data.corr()
# Out:
#            temp     tempc
# temp   1.000000  0.781955
# tempc  0.781955  1.000000

# %%
#put all the temperatures in one dataframe
tempdf = pd.DataFrame([intertemp['temp'].rename(f"{key}") for key, intertemp in station_intertemps.items()]).T

# %%
tdf = tempdf.join(img_temps, on='datetime')

# %%
tdf.corr()
# Out:
#           74410     KAQW0     KDXR0     KIJD0     72510     KNY00     KAFN0  \
# 74410  1.000000  0.958879  0.940349  0.884128  0.709701  0.908027  0.822428
# KAQW0  0.958879  1.000000  0.898770  0.797116  0.567429  0.874894  0.711427
# KDXR0  0.940349  0.898770  1.000000  0.866817  0.683442  0.870957  0.772819
# KIJD0  0.884128  0.797116  0.866817  1.000000  0.800095  0.801553  0.874328
# 72510  0.709701  0.567429  0.683442  0.800095  1.000000  0.631588  0.943865
# KNY00  0.908027  0.874894  0.870957  0.801553  0.631588  1.000000  0.766387
# KAFN0  0.822428  0.711427  0.772819  0.874328  0.943865  0.766387  1.000000
# 72522  0.929551  0.921615  0.887821  0.808488  0.626473  0.914409  0.754280
# KMMK0  0.910108  0.832027  0.933727  0.946062  0.749714  0.847309  0.829074
# KOXC0  0.906713  0.812632  0.940451  0.936762  0.792916  0.853052  0.859385
# KPOU0  0.910217  0.909357  0.908138  0.791936  0.547030  0.901376  0.679743
# KEEN0  0.938932  0.885199  0.905661  0.920002  0.777891  0.857680  0.892014
# KHFD0  0.896205  0.801102  0.919143  0.953957  0.787640  0.856585  0.867415
# KORE0  0.916969  0.849958  0.877072  0.942039  0.827262  0.819683  0.906810
# KSCH0  0.914314  0.901436  0.864412  0.811812  0.616689  0.962673  0.772314
# 72508  0.921756  0.853707  0.923652  0.947671  0.725019  0.868261  0.838283
# 74484  0.867961  0.784235  0.816818  0.800911  0.730385  0.867903  0.819118
# 74491  0.922905  0.873428  0.908948  0.942405  0.725798  0.845991  0.832676
# TMT7J  0.957734  0.957611  0.903327  0.811345  0.641240  0.911638  0.764870
# KBAF0  0.932086  0.888149  0.914087  0.924023  0.676428  0.860268  0.798616
# 72518  0.930004  0.914408  0.890236  0.805486  0.621076  0.964596  0.759448
# KVSF0  0.949497  0.891389  0.904253  0.899394  0.778672  0.908751  0.895512
# tempc  0.781955  0.647951  0.755725  0.865763  0.857362  0.684887  0.864961
#
#           72522     KMMK0     KOXC0  ...     KORE0     KSCH0     72508  \
# 74410  0.929551  0.910108  0.906713  ...  0.916969  0.914314  0.921756
# KAQW0  0.921615  0.832027  0.812632  ...  0.849958  0.901436  0.853707
# KDXR0  0.887821  0.933727  0.940451  ...  0.877072  0.864412  0.923652
# KIJD0  0.808488  0.946062  0.936762  ...  0.942039  0.811812  0.947671
# 72510  0.626473  0.749714  0.792916  ...  0.827262  0.616689  0.725019
# 74491  0.807883  1.000000  0.868658  0.976457  0.869714  0.926859  0.842713
# TMT7J  0.841544  0.868658  1.000000  0.879110  0.940340  0.916206  0.723386
# KBAF0  0.816179  0.976457  0.879110  1.000000  0.885846  0.926831  0.825298
# 72518  0.869470  0.869714  0.940340  0.885846  1.000000  0.920681  0.683250
# KVSF0  0.878881  0.926859  0.916206  0.926831  0.920681  1.000000  0.816053
# tempc  0.779065  0.842713  0.723386  0.825298  0.683250  0.816053  1.000000
#
# [23 rows x 23 columns]

# %%
corrs = tdf.corr()['tempc'].drop('tempc').sort_values()
corrs
# Out:
# KPOU0    0.618349
# KAQW0    0.647951
# KSCH0    0.653672
# 72518    0.683250
# KNY00    0.684887
# 72522    0.698216
# TMT7J    0.723386
# KDXR0    0.755725
# 74484    0.779065
# 74410    0.781955
# KVSF0    0.816053
# KBAF0    0.825298
# 72508    0.834544
# 74491    0.842713
# KHFD0    0.844746
# KEEN0    0.850326
# KMMK0    0.852122
# 72510    0.857362
# KOXC0    0.859084
# KAFN0    0.864961
# KIJD0    0.865763
# KORE0    0.895950
# Name: tempc, dtype: float64

# %%
#get station info to look at locations
stations
# Out:
#                                            name country region      wmo  icao  \
# id
# 74410                               Barkerville      US     MA  74410.0  KPSF
# KAQW0                  North Adams / Blackinton      US     MA      NaN  KAQW
# 72518              Albany International Airport      US     NY  72518.0  KALB
# KBAF0                 Westfield / Owen District      US     MA      NaN  KBAF
# TMT7J            Bennington Morse State Airport      US     VT      NaN  KDDH
# 74491  Chicopee Falls / Westover Air Force Base      US     MA  74491.0  KCEF
# 74484                           West Dover, Vt.      US     NY  74484.0  KN66
# 72508             Bradley International Airport      US     CT  72508.0  KBDL
# KSCH0            Schenectady / Stoodley Corners      US     NY      NaN  KSCH
# KORE0                   Orange / Partridgeville      US     MA      NaN  KORE
# K44N0                   Millbrook / Moores Mill      US     NY      NaN  K44N
# KHFD0      Hartford / Colonial Mobile Home Park      US     CT      NaN  KHFD
# KEEN0                      Keene / Spragueville      US     NH      NaN  KEEN
# KPOU0           Poughkeepsie  /  New Hackensack      US     NY      NaN  KPOU
# KOXC0                        Oxford / Southford      US     CT      NaN  KOXC
# KMMK0                   Meriden / South Meriden      US     CT      NaN  KMMK
# 72522        Glens Falls / Dix Mobile Home Park      US     NY  72522.0  KGFL
# KAFN0                                   Jaffrey      US     NH      NaN  KAFN
# KNY00                    Johnstown / Hale Mills      US     NY      NaN  KNY0
# 72510                  Worcester / West Tatnuck      US     MA  72510.0  KORH
# KIJD0            Willimantic / Mansfield Hollow      US     CT      NaN  KIJD
# KDXR0                      Danbury / Miry Brook      US     CT      NaN  KDXR
# KVSF0            Springfield / Kendricks Corner      US     VT      NaN  KVSF
#
#        latitude  longitude  elevation          timezone hourly_start  \
# id
# 74410   42.4200   -73.2800      364.0  America/New_York   2006-01-01
# KAQW0   42.6962   -73.1702      199.0  America/New_York   2006-01-01
# 72510  2024-09-27  1948-06-01  2024-12-30    1948-01-01  2022-01-01
# KIJD0  2024-09-27  2006-01-01  2022-04-24    2006-01-01  2021-01-01
# KDXR0  2024-09-27  2006-01-01  2022-04-24    2006-01-01  2021-01-01
# KVSF0  2024-09-27  2006-01-01  2022-04-20    2006-01-01  2021-01-01
#
#             distance
# id
# 74410    3770.579319
# KAQW0   32444.331538
# 72518   38898.798787
# KBAF0   51149.296510
# TMT7J   53930.441510
# 74491   62326.051383
# 74484   65724.708546
# 72508   69808.424977
# KSCH0   75119.326197
# KORE0   79791.989447
# K44N0   88267.570117
# KHFD0   89059.521047
# KEEN0   95951.936134
# KPOU0  102083.653518
# KOXC0  103748.506904
# KMMK0  105575.267054
# 72522  108078.379883
# KAFN0  110178.027618
# KNY00  110783.129955
# 72510  112966.523242
# KIJD0  114300.805830
# KDXR0  117092.834287
# KVSF0  119359.195468

# %%
stations = pd.read_csv('../weather-data/meteostat/stations_df.csv', index_col='id')
stations.head()
# Out:
#                                  name country region      wmo  icao  latitude  \
# id
# 74410                     Barkerville      US     MA  74410.0  KPSF   42.4200
# KAQW0        North Adams / Blackinton      US     MA      NaN  KAQW   42.6962
# 72518    Albany International Airport      US     NY  72518.0  KALB   42.7500
# KBAF0       Westfield / Owen District      US     MA      NaN  KBAF   42.1577
# TMT7J  Bennington Morse State Airport      US     VT      NaN  KDDH   42.8935
#
#        longitude  elevation          timezone hourly_start  hourly_end  \
# id
# 74410   -73.2800      364.0  America/New_York   2006-01-01  2024-09-27
# KAQW0   -73.1702      199.0  America/New_York   2006-01-01  2024-09-27
# 72518   -73.1333       87.0  America/New_York   1946-01-01  2024-09-27
# KBAF0   -72.7156       82.0  America/New_York   1973-01-05  2024-09-27
# TMT7J   -73.2486      252.0  America/New_York   2022-04-23  2024-09-27
#
#       daily_start   daily_end monthly_start monthly_end      distance
# id
# 74410  2006-01-01  2022-04-25    2006-01-01  2022-01-01   3770.579319
# KAQW0  2006-01-01  2022-04-23    2006-01-01  2022-01-01  32444.331538
# 72518  1938-06-01  2024-12-30    1938-01-01  2022-01-01  38898.798787
# KBAF0  1998-08-08  2022-04-24    2005-01-01  2022-01-01  51149.296510
# TMT7J         NaN         NaN           NaN         NaN  53930.441510

# %%
#where is Koreo?
stations.loc['KORE0']
# Out:
# name             Orange / Partridgeville
# country                               US
# region                                MA
# wmo                                  NaN
# icao                                KORE
# latitude                         42.5701
# longitude                       -72.2886
# elevation                          169.0
# timezone                America/New_York
# hourly_start                  1996-08-09
# hourly_end                    2024-09-27
# daily_start                   1996-08-11
# daily_end                     2022-04-24
# monthly_start                 2005-01-01
# monthly_end                   2022-01-01
# distance                    79791.989447
# Name: KORE0, dtype: object

# %%
#where is Koreo?
stations.loc['KIJD0']
# Out:
# name             Willimantic / Mansfield Hollow
# country                                      US
# region                                       CT
# wmo                                         NaN
# icao                                       KIJD
# latitude                                 41.744
# longitude                              -72.1802
# elevation                                  75.0
# timezone                       America/New_York
# hourly_start                         2006-01-01
# hourly_end                           2024-09-27
# daily_start                          2006-01-01
# daily_end                            2022-04-24
# monthly_start                        2006-01-01
# monthly_end                          2021-01-01
# distance                           114300.80583
# Name: KIJD0, dtype: object

# %%
#KAFN0?
stations.loc['KAFN0']
# Out:
# name                      Jaffrey
# country                        US
# region                         NH
# wmo                           NaN
# icao                         KAFN
# latitude                  42.8051
# longitude                 -72.003
# elevation                   317.0
# timezone         America/New_York
# hourly_start           2006-01-01
# hourly_end             2024-09-27
# daily_start            2006-01-01
# daily_end              2022-04-24
# monthly_start          2006-01-01
# monthly_end            2022-01-01
# distance            110178.027618
# Name: KAFN0, dtype: object

# %%
# KOXC0?
stations.loc['KOXC0']
# Out:
# name             Oxford / Southford
# country                          US
# region                           CT
# wmo                             NaN
# icao                           KOXC
# latitude                    41.4786
# longitude                  -73.1352
# elevation                     221.0
# timezone           America/New_York
# hourly_start             2006-01-01
# hourly_end               2024-09-27
# daily_start              2006-01-14
# daily_end                2022-04-24
# monthly_start            2007-01-01
# monthly_end              2022-01-01
# distance              103748.506904
# Name: KOXC0, dtype: object

# %%
# 72510

stations.loc['72510']
# Out:
# name             Worcester / West Tatnuck
# country                                US
# region                                 MA
# wmo                               72510.0
# icao                                 KORH
# latitude                          42.2673
# longitude                        -71.8757
# elevation                           308.0
# timezone                 America/New_York
# hourly_start                   1973-01-01
# hourly_end                     2024-09-27
# daily_start                    1948-06-01
# daily_end                      2024-12-30
# monthly_start                  1948-01-01
# monthly_end                    2022-01-01
# distance                    112966.523242
# Name: 72510, dtype: object

# %% [markdown]
# These correlations hint that the thing is in the far east of the circle. The reduced temperature variation may be due to forest cover or distance to nearby water. Is it in the Quabbin reservoir?
#
# Bought skydrop. My four secret words? Not tellin.

# %%
#draw these on a map

import geopandas as gpd

# usa = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# massachusetts = usa[usa['name'] == 'United States']

states = gpd.read_file('../naturalearthdata/ne_110m_admin_1_states_provinces_lines.shp')
statesarea = gpd.read_file('../naturalearthdata/ne_110m_admin_1_states_provinces.shp')
lakes = gpd.read_file('../naturalearthdata/ne_110m_lakes.shp')
rivers = gpd.read_file('../naturalearthdata/ne_110m_rivers_lake_centerlines.shp')

water = gpd.read_file('../naturalearthdata/USA_Detailed_Water_Bodies.shp')
#plot the map
fig, ax = plt.subplots(figsize=(10,10))
# ax.set_xlim(-74, -71)
# ax.set_ylim(41.5, 43.5)

ax.set_xlim(-74, -71)
ax.set_ylim(41.5, 43.5)

states.plot(ax=ax, color = 'black', linewidth = 1)
# statesarea.plot(ax=ax, color = 'green')
# rivers.plot(ax=ax, color ='blue')
# lakes.plot(ax=ax, color='blue')
water.plot(ax=ax, color='blue')
# Out:
# <Axes: >

# %%
stations = stations.join(corrs)
stations.rename(columns = {'tempc':'livetempc-corr'}, inplace=True)

# KDXR0  117092.834287        0.755725
# KVSF0  119359.195468        0.816053

# %%
#make gpd points from the matching weather stations

point_xys = [
    [record['longitude'], record['latitude']]
    for index, record in stations.iterrows()
]

station_points = gpd.GeoDataFrame(
    {"geometry": gpd.points_from_xy(stations['longitude'],stations['latitude'])},
    crs="EPSG:4326"
)

# stations.sort_values(by = 'livetempc-corr', ascending = False)[:5]
# Out:
#                                  name country region      wmo  icao  latitude  \
# id
# KORE0         Orange / Partridgeville      US     MA      NaN  KORE   42.5701
# KIJD0  Willimantic / Mansfield Hollow      US     CT      NaN  KIJD   41.7440
# KAFN0                         Jaffrey      US     NH      NaN  KAFN   42.8051
# KOXC0              Oxford / Southford      US     CT      NaN  KOXC   41.4786
# 72510        Worcester / West Tatnuck      US     MA  72510.0  KORH   42.2673
#
#        longitude  elevation          timezone hourly_start  hourly_end  \
# id
# KORE0   -72.2886      169.0  America/New_York   1996-08-09  2024-09-27
# KIJD0   -72.1802       75.0  America/New_York   2006-01-01  2024-09-27
# KAFN0   -72.0030      317.0  America/New_York   2006-01-01  2024-09-27
# KOXC0   -73.1352      221.0  America/New_York   2006-01-01  2024-09-27
# 72510   -71.8757      308.0  America/New_York   1973-01-01  2024-09-27
#
#       daily_start   daily_end monthly_start monthly_end       distance  \
# id
# KORE0  1996-08-11  2022-04-24    2005-01-01  2022-01-01   79791.989447
# KIJD0  2006-01-01  2022-04-24    2006-01-01  2021-01-01  114300.805830
# KAFN0  2006-01-01  2022-04-24    2006-01-01  2022-01-01  110178.027618
# KOXC0  2006-01-14  2022-04-24    2007-01-01  2022-01-01  103748.506904
# 72510  1948-06-01  2024-12-30    1948-01-01  2022-01-01  112966.523242
#
#        livetempc-corr
# id
# KORE0        0.895950
# KIJD0        0.865763
# KAFN0        0.864961
# KOXC0        0.859084
# 72510        0.857362

# %%
#zoom in around the Quabbin
#and plot the stations


fig, ax = plt.subplots(figsize=(10,10))
# ax.set_xlim(-74, -71)
# ax.set_ylim(41.5, 43.5)

ax.set_xlim(-72.9, -72.1)
ax.set_ylim(42., 42.9)

states.plot(ax=ax, color = 'black', linewidth = 1)
# statesarea.plot(ax=ax, color = 'green')
# rivers.plot(ax=ax, color ='blue')
# lakes.plot(ax=ax, color='blue')
water.plot(ax=ax, color='blue')


station_points.plot(ax=ax, color = 'black', markersize=30)
station_points.plot(ax=ax, color = 'orange', markersize=25)

for index, station in stations.iterrows():
    plt.text(x= station['longitude'], y=station['latitude'], s=station['name'])

# %%
fig, ax = plt.subplots(figsize=(10,10))
# ax.set_xlim(-74, -71)
# ax.set_ylim(41.5, 43.5)

ax.set_xlim(-74, -71)
ax.set_ylim(41.5, 43.5)

states.plot(ax=ax, color = 'black', linewidth = 1)
# statesarea.plot(ax=ax, color = 'green')
# rivers.plot(ax=ax, color ='blue')
# lakes.plot(ax=ax, color='blue')
water.plot(ax=ax, color='blue')
